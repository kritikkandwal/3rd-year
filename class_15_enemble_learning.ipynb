# %% [markdown]
# Ensemble learning --> where there are multiple machine learning algorithm implemented collectively it does not interfers in the machine learning proccess as a whole rather ehances the overall performance (where ever applicable).<br>
#
# There are 2 type of ensemble learning techniques:<br>
#
# 1) parallel elt<br>
# 2) sequential elt<br>.
#
# A) Parallel elt<br>
# In this technique the ML models are implemented in a parallel manner, where each model give its own set of pridictions. Followed by this an algorithm takes all these pridictions as an input to give the final set of output pridictions after different possible convugational implementations.

# %% [markdown]
# different possible computational implementation to give the final list of pridictions are listed below <br>
#
# 1) Voting <br>
# for example --> model 1 pridicts a set of samples as benine or maligmant in the cancer data set and model 2 also pridict the set of samples as bein and metastatic the voting classifier will give the final pridiction based on the majority . this classifier is mainly emplemented for categorical data <br>
#
# 2) when the pridiction value from multiple models are average to give the final set of pridictions this comes under the scenario of averaging method<br>
#
# in this machine laearning technique multiple machine learning model are used in the sequential manner, to train again after the first initial training the iteration is performed to improve on the errors . exmaples of sequential system includes boosting algorithms. these systems highly improved the accuracy values

# %% [markdown]
# K fold cross validation and cv score method <br>
#
# k fold technique provides the number of subset of data from which one subset at a time is iteratevly fed for training pruposes. It cannot act alone since it's only a declaration

# %% [markdown]
# CV score method and Cross validation score method <br>
#
# this method calcualates the relevant stastical outcomes for example accuracy values for each iterations as designated by the K-fold, for each model of the ensemble system.
#
# if a dataset has 100 points and k value is set to be then 5 mini dataset of 20 dataset each will be calculated for iterative training of each model resulting accuracy value for each iteration will be recorded and finally the mean of 5 accuracy values will be the representative training accuracy this technique adds creadibility to the final outputs also it's implemented for quick scanning of multiple model before finalizing the best performing model on a given data set <br>
#
# final implementation
# note 1 ) multiple model to be implemented in the solution are assembled through the variable name estimator
# note 2) voting classifier is implemented on the pridiction outcomes of the multiple models belonging to estimator , through a variable ensemble
#
# note 3) k fold declaration is performed
#
# note 4) cv score is implemented with the declared K fold and the ensemble created in note 2

# %% [markdown]
# stacking is the technique in which ml algorithm are implemented at multiple lvls. at lvl 0 - different models are implemented to give their individuals set of pridictions. These pridiction are then pooled to create one final dataset. this dataset is finally used asa training dataset for lvl 1 machine learning model single model to get the final set of pridictions, this method is a powerfull method that helps improved accuracy. algorithms like voting classifier and the averaging methods do not interfer with the overall stastical outcomes how ever techniques like stacking,boosting and bagging imact the stastical outcomes in the solutions
