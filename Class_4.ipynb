# %%
import pandas as pd

# %% [markdown]
# CLass imbalance : When one paticular class or a set of classes outnumbers the other then the phenomena of class imbalance is observed <br>
# Feature selection : feature selection is the process of simply including or excluding a specific set of features . The advantages of feature selection encludes <br>
# 1)better model performance <br>
# 2)time and cost optimisation<br>
# 3)prevention of overfitting<br>
# <br>
# Feature Selection is different from dimensionality deduction. In dimensionality deduction a new feature is created from existing multiple features. On the other hand feature selection is only including and excluding the features <br>
# DATA LOADING : There are different approaches for data loading. few examples described below<br>
# 1)csv files are loaded using read csv_method() <br>
# 2)excel files are loaded using read_excel()<br>
# 3)dictionaries(data present in the format of key value pairs )can be directly converted to data frames<br>
# 4)python list and arrays can be converted to data frames with right set of inputs like column headers using the right syntax <br>
# 5)data set in multiple formats can be first converted to csv format and then loaded as described in point no 1

# %% [markdown]
# Track a document excel sheet with complete all the steps with each step detailed action<b>
# contribution of each member of the group <br>
# status completed vs not completed <br>
# to be reported to the tracker document.

# %% [markdown]
# OVERVIEW OF BINARY CLASSIFICATION<br>
# batch AJ folder has 3 notebook 10.1,10.2,10.3<br>
# these 3 notebooks provide bare minimum inputs if the project involves classification algorithms. The project should provide 4 backbone commponents essentially <br>
# 1) complete data handling<br>
# 2) splitting the data <br>
# 3) training the algo<br>
# 4) testing the algorithm<br>
#
# classification is a tye of supervised machine learning approaches where the data set was divided into 2 or more classes. The trained algorithm decides the plain of sepration between the classes

# %% [markdown]
# Binary classificatio <br>
# when there are a toral of two classes in the dataset and the data coin have to be segregrated between two classes where the first classes labeled as <br>
# 1 class) positive or
# 2 class) zero (negative or )<br>
# Logistic regression<br>
# logistic regression is a supervsed machine learning algorithm with operating mathematical function called as the symboid function it's implemented for binnary classification. the output is the probabilty values which are inferred as likelihood values
