# %% [markdown]
# polynomial and ridge in --> dec
#
# POLYNOMIAL REGRESSION
# in polynomial regression the set of independent variable which are allocated as x-data set (x-train,x-test) are first transformed using a method called as polynomial feature the tranform data is channeled to a linear regression algorithm to continue with the training and testing process.the stastical outcomes of complete implementation are the routine outcomes namely NSE, MAE and R2 score.
#
# Polynomial feature is an algorithm that transforms the x_dataset (independent variable) to be channeled into linear regression machie learning algorithm.
#
# Linear regression - It implements a parameter named as "degree". The value of this parameter can be tuned, with a final goal to obtain best performance transformed to be implemented for the machine learning algorithms (Linear regression). The tunning of the parameters manually or using automated system have to be evaluated for there final impact. be it one parameter or more than one parameter tunning may involve different permutation and combinations when it comes to multiple parameters kokl

# %% [markdown]
# ridge regression is the linear regression that implements the concept of regularisation through the implementation of regularisation parameter. At first a default parameter value is implemented for the poc. along with the routine satastical outcomes. These critical outcomes includes the value of coefficents are comprehented as follows.

# %% [markdown]
# these critical coefficents are comprehended as follows :
# 1) if the value of coefficient is 0 then the corresponding feature doesnot contribute to the pridiction of target variable then this paticular feature contributes positively to the pridiction of Y-variable(target variable) lower the positive value ,lower the contribution/impact and higher the positive value higher the contribution/impact of the given feature of the given feature.
# Similarly the negative value of the coefficent implies the negative impact of that feature on the prediction of the Y-target variable

# %% [markdown]
# each group member has to be ready for the following
# 1) with full code
# 2) code for the full project end to end
# 3) marking is going to be student wise
# 4) same ppt which is the group ppt has to be handled by each member on the exam day
# 5) bring you laptops and phones
# 6) order of exam
# 7)

# %% [markdown]
# marking scheme
# When there are multiple parameters

# %% [markdown]
# in an integrated manner ,
# ridge cross validation--this is a method for a single parameter optimisation
#
# any of the cross validation technique to be shared during the viva.
